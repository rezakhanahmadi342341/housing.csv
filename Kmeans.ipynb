# %% [markdown]
# <a href="https://colab.research.google.com/github/rezakhanahmadi342341/housing.csv/blob/main/Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
x, y = make_blobs(n_features=2 , n_samples=300, centers=2)
plt.scatter(x[:,0], x[:,1], color='blue')
plt.show()

# %%
model = KMeans(n_clusters=3, random_state=42)
model.fit(x)
label = model.labels_
centers = model.cluster_centers_

# %%
plt.scatter(x[:,0], x[:,1], c=label)
plt.scatter(centers[:,0], centers[:,1], marker='x', color='red')
plt.show()
