# %% [markdown]
# <a href="https://colab.research.google.com/github/rezakhanahmadi342341/housing.csv/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from random import randint as rn

# %%
def mx(num, _min,_max):
  point = [rn(_min,_max) for  i in range(num)]
  return point

# %%
x = mx(100,0,100)
y = mx(100,0,100)

a = mx(5,0,100)
b = mx(5,0,100)

plt.scatter(x,y, label='x,y', alpha=0.7, c=mx(100,100,500), cmap='YlOrRd', edgecolors='black',
            linewidths=1.5
            )
plt.colorbar()
plt.title("scatter_plot")
plt.ylabel('scatter_y')
plt.xlabel('scatter_x')
plt.grid()
plt.legend()
plt.show()
